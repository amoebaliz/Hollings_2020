# %% [markdown]
# Identify the Python packages we will need to run the code

# %%
import matplotlib.pyplot as plt 
import matplotlib.ticker as mticker
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import cartopy.feature as cfeature
import cartopy.crs as ccrs
import pandas

# %% [markdown]
# Defining a function for plotting a map given a bunch of lat, lon locations. We don't have to use functions but they sometimes simplify code, especially when you want to do the same thing multiple times

# %%
def plot_reefs(lon, lat):
    fig = plt.figure(figsize=(12,4))
    ax = plt.axes(projection=ccrs.PlateCarree())
    ax.add_feature(cfeature.COASTLINE)
    ax.add_feature(cfeature.LAND)

    # parallels/meridiens
    gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True,
                      linewidth=2, color='gray', alpha=0.5, linestyle='--')
    gl.xlabels_top = False
    gl.ylabels_right = False
    gl.xlabel_style = {'size': 18, 'color': 'black'}
    gl.ylabel_style = {'size': 18, 'color': 'black'}

    plt.plot(lon, lat, 'ro',markersize=2)
    return fig

# %% [markdown]
# Here we identify the file containing reef locations and reed it into an array.

# %%
csv_fil = '/Users/lizdrenkard/TOOLS/Hollings_2020/ReefLocations.csv'
df = pandas.read_csv(csv_fil,encoding= 'unicode_escape')

# %% [markdown]
# Let's see what the pandas data set looks like (pandas is a package kindof like xarray that organizes datasets).

# %%
df
# Out:
#           ID   REGION          SUBREGION  COUNTRY        LOCATION       LAT  \
# 0         33      NaN                NaN      NaN             NaN   0.21667
# 1       7976      NaN                NaN      NaN             NaN   0.03333
# 2       3575      NaN                NaN      NaN             NaN  27.95000
# 3      10302      NaN                NaN      NaN             NaN  28.88333
# 4       3948      NaN                NaN      NaN             NaN  26.88333
# ...      ...      ...                ...      ...             ...       ...
# 10043   8289  Pacific  Southwest Pacific  Vanuatu  Torres Islands -13.40000
# 10044   8290  Pacific  Southwest Pacific  Vanuatu  Torres Islands -13.33333
# 10045   8291  Pacific  Southwest Pacific  Vanuatu  Torres Islands -13.31667
# 10046   8292  Pacific  Southwest Pacific  Vanuatu  Torres Islands -13.25000
# 10047   8293  Pacific  Southwest Pacific  Vanuatu  Torres Islands -13.15000
#
# ...

# %% [markdown]
# Submitting the lat,lons from the csv file to plot in a general, global map

# %%
import numpy as np
fig = plot_reefs(df['LON'],df['LAT'])
print(np.min(df['LAT']))
print(np.max(df['LAT']))
# Out:
# -37.5
# 34.08333
